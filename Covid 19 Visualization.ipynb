# %% [markdown]
# # AIM

# %% [markdown]
# The aim of this project is to make readers become aware of the devastating effect of the Corona Virus Pandemic by visualizing a graph that shows the top 20 countries by the number of deaths.
#
# We've already collected the data and added it in the top20_deathtoll.csv file (the data was collected from [Worldometer](https://www.worldometers.info/) on December 8, 2020):

# %%
import pandas as pd

# %%
top20_deathtoll = pd.read_csv('C://Users//MY PC//Desktop//DATASETS//top20_deathtoll.csv')

# %%
top20_deathtoll
# Out:
#    Country_Other  Total_Deaths
# 0         Turkey       15103.0
# 1          Chile       15663.0
# 2        Belgium       17386.0
# 3      Indonesia       18000.0
# 4        Germany       19539.0
# 5         Poland       20592.0
# 6   South Africa       22249.0
# 7           Peru       36324.0
# 8       Colombia       37995.0
# 9      Argentina       39888.0
# 10        Russia       44159.0
# 11         Spain       46646.0
# 12          Iran       50917.0
# 13        France       55521.0
# 14         Italy       60606.0
# 15            UK       61434.0
# 16        Mexico      110074.0
# 17         India      141005.0
# 18        Brazil      177388.0
# 19           USA      290798.0

# %% [markdown]
# We will now use a bar plot to visualize the graph

# %%
import matplotlib.pyplot as plt

# %%
top20_deathtoll.plot('Country_Other', 'Total_Deaths', kind='barh', color='red')

# %% [markdown]
# We need to maximize Data Ink ratio to make the users focus on the key information

# %%
fig, ax = plt.subplots()
ax.barh(top20_deathtoll['Country_Other'],
        top20_deathtoll['Total_Deaths'])
plt.show()

# %% [markdown]
# We will edit the figure size for mobile phone users.

# %%
fig, ax = plt.subplots(figsize=(4.5,6))
ax.barh(top20_deathtoll['Country_Other'], top20_deathtoll['Total_Deaths'])
plt.show()

# %%
fig,ax= plt.subplots(figsize=(4.5,6))
# to make the bar less thick, we can use the heigh=0.45
ax.barh(top20_deathtoll['Country_Other'], top20_deathtoll['Total_Deaths'], height=0.45, color='#af0b1e')
positions = ['left','right','bottom','top']
for position in positions:
    ax.spines[position].set_visible(False)
# to move the xtick labels to the top
ax.xaxis.tick_top()
# to remove the xticks
ax.tick_params(bottom=False, top=False, left=False, right=False, axis = 'x' , colors = 'grey')
# to remove the yticks
ax.tick_params(bottom=False, top=False, left=False, right=False, axis = 'y')
# to remove some of the xtick labels, ax.set_xticks()
ax.set_xticks([0, 150000, 300000])
ax.text(x=-80000, y=23.5, s= 'The Death Toll Worldwide Is 1.5M+', weight='bold', size=17)
ax.text(x=-80000, y=22.5, s= 'Top 20 countries by death toll (December 2020)', size=12)
# To add comma to 150000, 300000
ax.set_xticklabels(['0', '150,000', '300,000'])
# to left align the country names
# first,remove the county names
ax.set_yticklabels([])
country_names = top20_deathtoll['Country_Other']
for i, country in zip(range(0,21), country_names):
    ax.text(x=-80000, y=i-0.15, s=country)
# to add a vertical line, and other effects, the alpha makes it transparent

plt.show()

# %% [markdown]
# We need to add a vertical line across the graph to aid readers in interpreting the plots

# %%
fig,ax= plt.subplots(figsize=(4.5,6))
# to make the bar less thick, we can use the heigh=0.45
ax.barh(top20_deathtoll['Country_Other'], top20_deathtoll['Total_Deaths'], height=0.45, color='#af0b1e')
positions = ['left','right','bottom','top']
for position in positions:
    ax.spines[position].set_visible(False)
# to move the xtick labels to the top
ax.xaxis.tick_top()
# to remove the xticks
ax.tick_params(bottom=False, top=False, left=False, right=False, axis = 'x' , colors = 'grey')
# to remove the yticks
ax.tick_params(bottom=False, top=False, left=False, right=False, axis = 'y')
# to remove some of the xtick labels, ax.set_xticks()
ax.set_xticks([0, 150000, 300000])
ax.text(x=-80000, y=23.5, s= 'The Death Toll Worldwide Is 1.5M+', weight='bold', size=17)
ax.text(x=-80000, y=22.5, s= 'Top 20 countries by death toll (December 2020)', size=12)
# To add comma to 150000, 300000
ax.set_xticklabels(['0', '150,000', '300,000'])
# to left align the country names
# first,remove the county names
ax.set_yticklabels([])
country_names = top20_deathtoll['Country_Other']
for i, country in zip(range(0,21), country_names):
    ax.text(x=-80000, y=i-0.15, s=country)
# to add a vertical line, and other effects, the alpha makes it transparent
ax.axvline(x=150000, ymin=0.045, c='grey', alpha=0.5)

plt.show()

# %% [markdown]
# From the plot above, the country with the highest number of death as at December 2020 is The United States of America with about 300, 000 deaths. Next inline is Brazil with more than 150, 000 deaths.

# %% [markdown]
# # Story Telling

# %% [markdown]
# Taking the United States as a case study, we want to show how the death toll has changed since the begining of the pandemic. We collected the data from the [World Health Organization](https://covid19.who.int/) on December 15th, 2020.

# %%
death_toll = pd.read_csv('C://Users//MY PC//Desktop//DATASETS//covid_avg_deaths.csv')

# %%
death_toll
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
deaths = [2398, 126203, 227178, 295406]
proportions = [round(death/295406, 2) for death in deaths]
xmax_vals = [round(0.5 + proportion * 0.3, 3) for proportion in proportions]
fig,(ax1,ax2,ax3,ax4)= plt.subplots(nrows=4, ncols=1, figsize=(6,8))
axes = [ax1, ax2, ax3, ax4]
for ax in axes:
    #ploting the month against New_deaths, and setting the transparency with the alpha parameter
    ax.plot(death_toll['Month'], death_toll['New_deaths'], color = '#af0b1e', alpha=0.1, 
            linewidth=2.5)
    # removing the tick and tick labels
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.tick_params(bottom=False, left= False)
    for pos in ['left','bottom','right','top']:
        ax.spines[pos].set_visible(False)
ax1.plot(death_toll['Month'][:3], death_toll['New_deaths'][:3], color = '#af0b1e', 
            linewidth=2.5)
ax2.plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6], color = '#af0b1e',
            linewidth=2.5)
ax3.plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10], color = '#af0b1e', 
            linewidth=2.5)
ax4.plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12], color = '#af0b1e', 
            linewidth=2.5)
ax1.text(0.5, -80, '0', alpha=0.5)
ax1.text(3.5, 2000, '1,844', alpha=0.5)
ax1.text(11.5, 2400, '2,247', alpha=0.5)
ax1.text(1.0, -300, 'Jan - Mar', color='#af0b1e', weight='bold', rotation=1)
ax2.text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
ax3.text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
ax4.text(10.5, 600,'Oct - Dec', color='#af0b1e', weight='bold', rotation = 45)
ax1.text(x=0.5, y=3500, s='The virus kills 851 people each day', weight='bold', size ='14')
ax1.text(x=0.5, y=3150, s='Average number of daily deaths per month in the US', size ='12')
for ax, xmax, death in zip(axes, xmax_vals, deaths):
    ax.axhline(y=1600, xmin=0.5, xmax=0.8,
               linewidth=6, color='#af0b1e',
               alpha=0.1)
    ax.axhline(y=1600, xmin=0.5, xmax=xmax,
               linewidth=6, color='#af0b1e')
    ax.text(7.5, 1850, format(death, ','),
            color='#af0b1e', weight='bold')
plt.show()

# %% [markdown]
# This data story shows the evolution of the death toll in the United States. At the end of March, we see the death toll at 2,398 deaths, but in December, it became 295,406 — it has changed. Following the four line plots, we see a sequence of events that led to that change. For instance, a surge in the average number of daily deaths starting in April resulted in a large number of deaths at the end of June.
